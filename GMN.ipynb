# %% [markdown]
# <a href="https://colab.research.google.com/github/nipa0823/bun/blob/main/GMN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install transformers sentencepiece flask flask_cors
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 4.2 MB 4.8 MB/s
# ...
#      |████████████████████████████████| 1.2 MB 53.2 MB/s
# ...
#      |████████████████████████████████| 86 kB 5.1 MB/s
# ...
#      |████████████████████████████████| 6.6 MB 40.1 MB/s
# ...
#      |████████████████████████████████| 596 kB 47.2 MB/s
# ...
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# ...

# %%
from transformers import T5Tokenizer, AutoModelForCausalLM 
tokenizer = T5Tokenizer.from_pretrained("rinna/japanese-gpt-1b") 
model = AutoModelForCausalLM.from_pretrained("rinna/japanese-gpt-1b")
# Out:
# Downloading:   0%|          | 0.00/1.00M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/153 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/283 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/578 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/2.47G [00:00<?, ?B/s]

# %%
def gencon(pre):
  print(pre)
  global tokenizer,model
  input = tokenizer.encode(pre, return_tensors="pt") 
  output = model.generate(input, do_sample=True, max_length=len(pre)+30, num_return_sequences=1) 
  return tokenizer.batch_decode(output)[0]

# %%
from flask import Flask, request
from flask_cors import CORS
app = Flask(__name__)
@app.route('/')
def index():
  return gencon(request.args["pre"])
CORS(app,supports_credentials=True)

# %%
# !wget https://github.com/cloudflare/cloudflared/releases/latest/download/cloudflared-linux-amd64.deb
# !apt install -y ./cloudflared-linux-amd64.deb
# Out:
# --2022-06-02 10:03:30--  https://github.com/cloudflare/cloudflared/releases/latest/download/cloudflared-linux-amd64.deb
# Resolving github.com (github.com)... 140.82.113.4
# Connecting to github.com (github.com)|140.82.113.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://github.com/cloudflare/cloudflared/releases/download/2022.5.3/cloudflared-linux-amd64.deb [following]
# --2022-06-02 10:03:31--  https://github.com/cloudflare/cloudflared/releases/download/2022.5.3/cloudflared-linux-amd64.deb
# Reusing existing connection to github.com:443.
# HTTP request sent, awaiting response... 302 Found
# ...

# %%
import threading
import time

threading.Thread(target=app.run).start()
time.sleep(3)
# !cloudflared tunnel --url localhost:5000
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)
# 2022-06-02T10:03:44Z INF Thank you for trying Cloudflare Tunnel. Doing so, without a Cloudflare account, is a quick way to experiment and try it out. However, be aware that these account-less Tunnels have no uptime guarantee. If you intend to use Tunnels in production you should use a pre-created named tunnel by following: https://developers.cloudflare.com/cloudflare-one/connections/connect-apps
# 2022-06-02T10:03:44Z INF Requesting new quick Tunnel on trycloudflare.com...
# 2022-06-02T10:03:45Z INF +--------------------------------------------------------------------------------------------+
# ...
